# %%
!  pip install --upgrade watson-developer-cloud
# Out:
# Collecting watson-developer-cloud
#   Downloading https://files.pythonhosted.org/packages/fc/a5/a89fc49bd82eb6ea569e45b43383c28cd51b5076f43010dcc3331c137ff5/watson-developer-cloud-2.10.1.tar.gz (248kB)
#      |████████████████████████████████| 256kB 5.0MB/s
# Requirement already satisfied, skipping upgrade: requests<3.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from watson-developer-cloud) (2.21.0)
# Requirement already satisfied, skipping upgrade: python_dateutil>=2.5.3 in /usr/local/lib/python3.6/dist-packages (from watson-developer-cloud) (2.5.3)
# Collecting websocket-client==0.48.0 (from watson-developer-cloud)
#   Downloading https://files.pythonhosted.org/packages/8a/a1/72ef9aa26cfe1a75cee09fc1957e4723add9de098c15719416a1ee89386b/websocket_client-0.48.0-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 38.5MB/s
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->watson-developer-cloud) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->watson-developer-cloud) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->watson-developer-cloud) (2019.3.9)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.0->watson-developer-cloud) (3.0.4)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python_dateutil>=2.5.3->watson-developer-cloud) (1.12.0)
# Building wheels for collected packages: watson-developer-cloud
#   Building wheel for watson-developer-cloud (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/ea/a7/19/fac0a408a586265eb374005308a7553d4494ab41b2fd88f5bc
# Successfully built watson-developer-cloud
# Installing collected packages: websocket-client, watson-developer-cloud
# Successfully installed watson-developer-cloud-2.10.1 websocket-client-0.48.0

# %%
import json
from watson_developer_cloud import VisualRecognitionV3

visual_recognition = VisualRecognitionV3(
    '2018-03-19',
    iam_apikey='{api_key}')

url = 'https://watson-developer-cloud.github.io/doc-tutorial-downloads/visual-recognition/Ginni_Rometty_at_the_Fortune_MPW_Summit_in_2011.jpg'

classes_result = visual_recognition.classify(url=url).get_result()
print(json.dumps(classes_result, indent=2))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "official",
#               "score": 0.62,
#               "type_hierarchy": "/person/official"
#             },
#             {
#               "class": "person",
#               "score": 0.772
#             },
#             {
#               "class": "state treasurer",
#               "score": 0.544,
#               "type_hierarchy": "/person/state treasurer"
#             },
#             {
#               "class": "people",
#               "score": 0.531,
#               "type_hierarchy": "/person/people"
#             },
#             {
#               "class": "resident commissioner",
#               "score": 0.5,
#               "type_hierarchy": "/person/resident commissioner"
#             }
#           ]
#         }
#       ],
#       "source_url": "https://watson-developer-cloud.github.io/doc-tutorial-downloads/visual-recognition/Ginni_Rometty_at_the_Fortune_MPW_Summit_in_2011.jpg",
#       "resolved_url": "https://watson-developer-cloud.github.io/doc-tutorial-downloads/visual-recognition/Ginni_Rometty_at_the_Fortune_MPW_Summit_in_2011.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 0
# }
